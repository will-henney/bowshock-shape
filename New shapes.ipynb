# %%
import numpy as np
import json

# %% [markdown]
# ## Look at the $A$ as a function of $\beta$

# %%
data = json.load(open("rc-r0.json"))

# %%
data.keys()
# Out:
# [u'proplyd', u'isotropic']

# %%
betastrings = data['proplyd'].keys()
betas = np.array([float(b) for b in sorted(betastrings)])

# %%
fig, (ax1, ax2) = subplots(1, 2)
for model, style, alpha in ['isotropic', 'o', 0.3], ['proplyd', '.', 0.8]:
    Ns = [len(data[model][beta]['inc']) for beta in sorted(betastrings)]
    N = max(Ns)
    print Ns, N
    for i in np.arange(0, N, 8):
        incs = [data[model][beta]['inc'][i] for beta in sorted(betastrings) 
                if i < len(data[model][beta]['inc'])]
#        assert np.alltrue([inc == incs[0] for inc in incs]), (i, incs)
        Rcs = [data[model][beta]['Rc'][i] for beta in sorted(betastrings)
               if i < len(data[model][beta]['inc'])]
        R0s = [data[model][beta]["R0'"][i] for beta in sorted(betastrings)
               if i < len(data[model][beta]['inc'])]
        Rcs = np.array(Rcs)
        R0s = np.array(R0s)
        m = len(Rcs)
        ax1.plot(betas[:m], Rcs/R0s, style, lw=2, alpha=alpha,
             label="{}: i = {:.1f}".format(model, np.degrees(incs[0])))
        ax2.plot(betas[:m], R0s/np.cos(incs[0]), style, lw=2, alpha=alpha)
ax1.fill_between([betas[0], betas[-1]], [1.0, 1.0], [2.0, 2.0], alpha=0.1)
ax2.fill_between([betas[0], betas[-1]], [0.1, 0.1], [0.35, 0.35], alpha=0.1)
ax1.set_ylim(0.0, 4.0)
ax2.set_ylim(0.0, 1.5)
ax1.set_ylabel("A' = Rc'/R0'")
ax1.set_xlabel("beta")
ax2.set_ylabel("R0'/D'")
ax2.set_xlabel("beta")
#ax1.legend(ncol=2, loc="lower right")
fig.set_size_inches(16, 12)
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100] 100
# [90, 86, 84, 82, 80, 79, 78, 77, 76, 75, 74, 73, 72, 72, 71, 70, 70, 69, 69, 68, 67, 67, 66, 66, 65, 65, 65, 64, 64, 63, 63, 62, 62, 62, 61, 61, 61, 60, 60, 59, 59, 59, 58, 58, 58, 57, 57, 57, 57, 56] 90

# %% [markdown]
# So this illustrates the large difference between the proplyd and isotropic models.   *But note that the different color sequences do **not** correspond to constant inclination*

# %% [markdown]
# Plot points in the $(\beta, i)$ plane, and maybe even interpolate to do contour maps.

# %%
fig, axes = subplots(2, 2, sharex=True)
for model, (axleft, axright) in zip(["proplyd", "isotropic"], axes):
    betas = []
    incs = []
    Rcs = []
    R0s = []
    for beta, bdata in data[model].items():
        for inc, Rc, R0 in
        betas.append

# %% [markdown]
# ### Conic sections again

# %%
import sys
sys.path.append("./read-shapes-LL")
import conic_utils

# %%
reload(conic_utils)
# Out:
# <module 'conic_utils' from './read-shapes-LL/conic_utils.py'>

# %%
size = 2.4
for theta_inf in [-45.0, -30.0, 0.0, 30.0, 40.0, 45.0, 50.0]:
    x, y = conic_utils.world_hyperbola(Rh=1.0, thh=theta_inf, PAh=90.0, xxh=0.0, yyh=0.0,
                                       xmin=-size, xmax=size, N=500, full=True)
    m = np.isfinite(x) & np.isfinite(y)
    plot(x[m], y[m], label="theta_inf = {:.0f}".format(theta_inf))
                  
#xlim(-0.3*size, size)
#ylim(-0.0*size, 1.3*size)
xlim(-size, size)
ylim(-size, size)
grid()
legend(loc='upper right')
xlabel('x')
ylabel('y')
xticks([0.0, 0.5, 1.0])
yticks([0.0, 0.5, 1.0])
gcf().set_size_inches(8, 8)

# %%
y[m]
# Out:
# array([ 0.83887776,  0.83326653,  0.82765531,  0.82204409,  0.81643287,
#         0.81082164,  0.80521042,  0.7995992 ,  0.79398798,  0.78837675,
#         0.78276553,  0.77715431,  0.77154309,  0.76593186,  0.76032064,
#         0.75470942,  0.7490982 ,  0.74348697,  0.73787575,  0.73226453,
#         0.72665331,  0.72104208,  0.71543086,  0.70981964,  0.70420842,
#         0.69859719,  0.69298597,  0.68737475,  0.68176353,  0.6761523 ,
#         0.67054108,  0.66492986,  0.65931864,  0.65370741,  0.64809619,
#         0.64248497,  0.63687375,  0.63126253,  0.6256513 ,  0.62004008,
#         0.61442886,  0.60881764,  0.60320641,  0.59759519,  0.59198397,
#         0.58637275,  0.58076152,  0.5751503 ,  0.56953908,  0.56392786,
#         0.55831663,  0.55270541,  0.54709419,  0.54148297,  0.53587174,
#         0.53026052,  0.5246493 ,  0.51903808,  0.51342685,  0.50781563,
#         0.50220441,  0.49659319,  0.49098196,  0.48537074,  0.47975952,
#         0.4741483 ,  0.46853707,  0.46292585,  0.45731463,  0.45170341,
#         0.44609218,  0.44048096,  0.43486974,  0.42925852,  0.42364729,
#         0.41803607,  0.41242485,  0.40681363,  0.4012024 ,  0.39559118,
#         0.38997996,  0.38436874,  0.37875752,  0.37314629,  0.36753507,
#         0.36192385,  0.35631263,  0.3507014 ,  0.34509018,  0.33947896,
#         0.33386774,  0.32825651,  0.32264529,  0.31703407,  0.31142285,
#         0.30581162,  0.3002004 ,  0.29458918,  0.28897796,  0.28336673,
#         0.27775551,  0.27214429,  0.26653307,  0.26092184,  0.25531062,
#         0.2496994 ,  0.24408818,  0.23847695,  0.23286573,  0.22725451,
#         0.22164329,  0.21603206,  0.21042084,  0.20480962,  0.1991984 ,
#         0.19358717,  0.18797595,  0.18236473,  0.17675351,  0.17114228,
#         0.16553106,  0.15991984,  0.15430862,  0.14869739,  0.14308617,
#         0.13747495,  0.13186373,  0.12625251,  0.12064128,  0.11503006,
#         0.10941884,  0.10380762,  0.09819639,  0.09258517,  0.08697395,
#         0.08136273,  0.0757515 ,  0.07014028,  0.06452906,  0.05891784,
#         0.05330661,  0.04769539,  0.04208417,  0.03647295,  0.03086172,
#         0.0252505 ,  0.01963928,  0.01402806,  0.00841683,  0.00280561,
#        -0.00280561, -0.00841683, -0.01402806, -0.01963928, -0.0252505 ,
#        -0.03086172, -0.03647295, -0.04208417, -0.04769539, -0.05330661,
#        -0.05891784, -0.06452906, -0.07014028, -0.0757515 , -0.08136273,
#        -0.08697395, -0.09258517, -0.09819639, -0.10380762, -0.10941884,
#        -0.44609218, -0.44048096, -0.43486974, -0.42925852, -0.42364729,
#        -0.41803607, -0.41242485, -0.40681363, -0.4012024 , -0.39559118,
#        -0.38997996, -0.38436874, -0.37875752, -0.37314629, -0.36753507,
#        -0.36192385, -0.35631263, -0.3507014 , -0.34509018, -0.33947896,
#        -0.33386774, -0.32825651, -0.32264529, -0.31703407, -0.31142285,
#        -0.30581162, -0.3002004 , -0.29458918, -0.28897796, -0.28336673,
#        -0.27775551, -0.27214429, -0.26653307, -0.26092184, -0.25531062,
#        -0.2496994 , -0.24408818, -0.23847695, -0.23286573, -0.22725451,
#        -0.22164329, -0.21603206, -0.21042084, -0.20480962, -0.1991984 ,
#        -0.19358717, -0.18797595, -0.18236473, -0.17675351, -0.17114228,
#        -0.16553106, -0.15991984, -0.15430862, -0.14869739, -0.14308617,
#        -0.13747495, -0.13186373, -0.12625251, -0.12064128, -0.11503006,
#        -0.10941884, -0.10380762, -0.09819639, -0.09258517, -0.08697395,
#        -0.08136273, -0.0757515 , -0.07014028, -0.06452906, -0.05891784,
#        -0.05330661, -0.04769539, -0.04208417, -0.03647295, -0.03086172,
#        -0.0252505 , -0.01963928, -0.01402806, -0.00841683, -0.00280561,
#         0.00280561,  0.00841683,  0.01402806,  0.01963928,  0.0252505 ,
#         0.03086172,  0.03647295,  0.04208417,  0.04769539,  0.05330661,
#         0.05891784,  0.06452906,  0.07014028,  0.0757515 ,  0.08136273,
#         0.08697395,  0.09258517,  0.09819639,  0.10380762,  0.10941884,
#         0.11503006,  0.12064128,  0.12625251,  0.13186373,  0.13747495,
#         0.14308617,  0.14869739,  0.15430862,  0.15991984,  0.16553106,
#         0.17114228,  0.17675351,  0.18236473,  0.18797595,  0.19358717,
#         0.1991984 ,  0.20480962,  0.21042084,  0.21603206,  0.22164329,
#         0.22725451,  0.23286573,  0.23847695,  0.24408818,  0.2496994 ,
#         0.25531062,  0.26092184,  0.26653307,  0.27214429,  0.27775551,
#         0.28336673,  0.28897796,  0.29458918,  0.3002004 ,  0.30581162,
#         0.31142285,  0.31703407,  0.32264529,  0.32825651,  0.33386774,
#         0.33947896,  0.34509018,  0.3507014 ,  0.35631263,  0.36192385,
#         0.36753507,  0.37314629,  0.37875752,  0.38436874,  0.38997996,
#         0.39559118,  0.4012024 ,  0.40681363,  0.41242485,  0.41803607,
#         0.42364729,  0.42925852,  0.43486974,  0.44048096,  0.44609218,
#         0.45170341,  0.45731463,  0.46292585,  0.46853707,  0.4741483 ,
#         0.47975952,  0.48537074,  0.49098196,  0.49659319,  0.50220441,
#         0.50781563,  0.51342685,  0.51903808,  0.5246493 ,  0.53026052,
#         0.53587174,  0.54148297,  0.54709419,  0.55270541,  0.55831663,
#         0.56392786,  0.56953908,  0.5751503 ,  0.58076152,  0.58637275,
#         0.59198397,  0.59759519,  0.60320641,  0.60881764,  0.61442886,
#         0.62004008,  0.6256513 ,  0.63126253,  0.63687375,  0.64248497,
#         0.64809619,  0.65370741,  0.65931864,  0.66492986,  0.67054108,
#         0.6761523 ,  0.68176353,  0.68737475,  0.69298597,  0.69859719,
#         0.70420842,  0.70981964,  0.71543086,  0.72104208,  0.72665331,
#         0.73226453,  0.73787575,  0.74348697,  0.7490982 ,  0.75470942,
#         0.76032064,  0.76593186,  0.77154309,  0.77715431,  0.78276553,
#         0.78837675,  0.79398798,  0.7995992 ,  0.80521042,  0.81082164,
#         0.81643287,  0.82204409,  0.82765531,  0.83326653,  0.83887776])

# %% [markdown]
# ## Compare a proplyd and isotropic model with the same value of $A$

# %%
pdata = json.load(open("CRW-shapes/proplyd-beta-0.02-arcdata.json"))['outer']['i=0.0']
idata = json.load(open("CRW-shapes/isotropic-beta-0.001-arcdata.json"))['outer']['i=0.0']
iidata = json.load(open("CRW-shapes/isotropic-beta-0.01-arcdata.json"))['outer']['i=0.0']

# %%
pdata['Rc'], idata['Rc'], iidata['Rc']
# Out:
# (0.22060970743143418, 0.05450218362136844, 0.17482837510555552)

# %%
xp, yp = np.array(pdata['x']), np.array(pdata['y'])
xi, yi = np.array(idata['x']), np.array(idata['y'])
xii, yii = np.array(iidata['x']), np.array(iidata['y'])

# %%
R0p = xp.max()
R0i = xi.max()
R0ii = xii.max()
xp /= R0p
yp /= R0p
xi /= R0i
yi /= R0i
xii /= R0ii
yii /= R0ii

# %%
Rcp = pdata['Rc']/R0p
Rci = idata['Rc']/R0i
Rcii = iidata['Rc']/R0ii
Rcp, Rci, Rcii
# Out:
# (1.7805559086349081, 1.7780125605838522, 1.9231121261611106)

# %%
Rc = Rcp
th = np.linspace(0.0, np.pi)
xc, yc = Rc*np.cos(th) - (Rc - 1), Rc*np.sin(th)


plot(xp, yp)
plot(xi, yi)
#plot(xii, yii)
plot(xc, yc)

for theta in [25., 30., 35.]:
    xcc, ycc = conic_utils.world_hyperbola(Rh=Rc, thh=theta, 
                                           PAh=90.0, xxh=-(Rc - 1.), yyh=0.0,
                                           xmin=-3., xmax=3., N=500, full=True)
    plot(xcc, ycc)

xlim(-2.0, 1.0)
ylim(0.0, 3.0)
grid()
gcf().set_size_inches(8, 8)

# %%
def polar(x, y, x0=0):
    return np.hypot(x-x0, y), np.arctan2(y, x-x0)

rp, thp = polar(xp, yp, x0=-(Rc - 1.))
rc, thc = polar(xc, yc, x0=-(Rc - 1.))
plot(np.degrees(thp), rp)
plot(np.degrees(thc), rc)

for theta in [25., 30., 35.]:
    xcc, ycc = conic_utils.world_hyperbola(Rh=Rc, thh=theta, 
                                           PAh=90.0, xxh=-(Rc - 1.), yyh=0.0,
                                           xmin=-3., xmax=3., N=500, full=True)
    rcc, thcc = polar(xcc, ycc, x0=-(Rc - 1.))
    plot(np.degrees(thcc), rcc, label=str(theta))
xlim(0.0, 120.0)
ylim(0.9*Rc, 2.1*Rc)
legend(loc="upper left")
xlabel('Theta around center of curvature')
ylabel('Radius from center of curvature')
gcf().set_size_inches(10, 10)

# %%
np.hstack((a, a))
# Out:
# array([0, 1, 2, 3, 0, 1, 2, 3])
